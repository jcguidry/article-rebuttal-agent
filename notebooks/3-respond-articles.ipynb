# %%
# !pip install langchain==0.0.346
# !pip install newspaper3k==0.2.8
# !pip install pandas==2.1.3
# !pip install deltalake==0.14.0
# !pip install tabulate==0.9.0
# !pip install googlenews
# !pip install gnews==0.3.6
# !pip install plotly==5.18.0
# ! pip install nbformat==5.9.2
# !pip install openai==1.3.7
# !pip install pyaml==23.9.7
# !pip show

# %%
import sys
sys.path.append('..')

import os
import json
import pandas as pd

from tabulate import tabulate
from IPython.display import display, Markdown
# TEST

from datetime import datetime, timedelta
import pytz

from deltalake import DeltaTable
from deltalake.writer import write_deltalake

from openai import OpenAI

import yaml

OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

# %%
with open('../config.yml', 'r') as file:
    config = yaml.safe_load(file)

query = config['query']
days_lookback = config['days_lookback']
max_results = config['max_results']

config
# Out:
# {'query': 'Eli Lilly Ozempic Risks', 'days_lookback': 90, 'max_results': 1000}

# %%
# Params
table_path_in = '../data/articles-scored'
table_path_out = '../data/articles-responded'
# --------------------------------------------

# query = "Ozempic"
# days_lookback = 30

current_datetime = datetime.now().astimezone(pytz.utc)
current_date = current_datetime.date()
start_date = (current_datetime - timedelta(days=days_lookback)).date()

# --------------------------------------------

start_date_str = str(start_date.strftime("%Y-%m-%d"))
current_date_str = str(current_date.strftime("%Y-%m-%d"))

print(
    f"""
    end_date: {current_date}
    start_date: {start_date}
    
    
    days_lookback: {days_lookback}
    """
)
# Out:
#     end_date: 2023-12-13
#     start_date: 2023-09-14
#
#
#     days_lookback: 90

# %%
# Query queries that have been ingested
DeltaTable(table_path_in).to_pandas(columns=['query']).value_counts()
# Out:
# query
# Eli Lilly Ozempic Risks    70
# Name: count, dtype: int64

# %%
df = DeltaTable(table_path_in).to_pandas(
    filters=[
        ('query','=',query),
        ('published date str','>', start_date_str),
    ]
)

df = df.loc[df['article text'].notna()] # can remove articles where scraping failed

df.head(1)
# Out:
#                                                title  \
# 0  Intestinal Blockage Added as Potential Ozempic...
#
#                                          description published date  \
# 0  Intestinal Blockage Added as Potential Ozempic...     2023-10-04
#
#                                                  url  \
# 0  https://news.google.com/rss/articles/CBMiUmh0d...
#
#                                            publisher                    query  \
# 0  {'href': 'https://www.drugwatch.com', 'title':...  Eli Lilly Ozempic Risks
#
#               query end date  published datetime published date str  \
# 0 2023-12-13 02:07:22.818228 2023-10-04 07:00:00         2023-10-04
#
#                                         article text  \
# 0  The U.S. Food and Drug Administration has adde...
#
#                                         article html  \
# 0  <!DOCTYPE html>\n<!--[if lt IE 8]>      <html ...
#
#                                      article summary  \
# 0  Other side effects of Ozempic already listed o...
#
#                                     article keywords  \
# 0  [blockage, effects, drug, fda, intestinal, weg...
#
#                                     sentiment_prompt sentiment_score  \
# 0  \n    - Your task is to read the article below...               9
#
#                                sentiment_explanation  \
# 0  The sentiment score is high due to the numerou...
#
#                                      negative_claims  __index_level_0__
# 0  - Intestinal blockage (ileus) added as a poten...                 76

# %%
df = df.sort_values(by=['sentiment_score'], ascending=False)
df.head(2)
# Out:
#                                                 title  \
# 0   Intestinal Blockage Added as Potential Ozempic...
# 12  Florida pharmacies selling GLP-1 knockoffs fac...
#
#                                           description published date  \
# 0   Intestinal Blockage Added as Potential Ozempic...     2023-10-04
# 12  Florida pharmacies selling GLP-1 knockoffs fac...     2023-11-30
#
#                                                   url  \
# 0   https://news.google.com/rss/articles/CBMiUmh0d...
# 12  https://news.google.com/rss/articles/CBMif2h0d...
#
#                                             publisher  \
# 0   {'href': 'https://www.drugwatch.com', 'title':...
# 12  {'href': 'https://www.fiercepharma.com', 'titl...
#
#                       query             query end date  published datetime  \
# 0   Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-04 07:00:00
# 12  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-30 08:00:00
#
#    published date str                                       article text  \
# 0          2023-10-04  The U.S. Food and Drug Administration has adde...
# 12         2023-11-30  Seven weeks after a federal judge dismissed (P...
#
#                                          article html  \
# 0   <!DOCTYPE html>\n<!--[if lt IE 8]>      <html ...
# 12  <!DOCTYPE html>\n<html lang="en" dir="ltr" pre...
#
#                                       article summary  \
# 0   Other side effects of Ozempic already listed o...
# 12  Seven weeks after a federal judge dismissed (P...
#
#                                      article keywords  \
# 0   [blockage, effects, drug, fda, intestinal, weg...
# 12  [drugs, versions, lawsuits, companies, knockof...
#
#                                      sentiment_prompt sentiment_score  \
# 0   \n    - Your task is to read the article below...               9
# 12  \n    - Your task is to read the article below...               9
#
#                                 sentiment_explanation  \
# 0   The sentiment score is high due to the numerou...
# 12  The sentiment score is given a 9 because the a...
#
#                                       negative_claims  __index_level_0__
# 0   - Intestinal blockage (ileus) added as a poten...                 76
# 12  - Novo Nordisk alleges that Brooksville Pharma...                 52

# %% [markdown]
# ## process for prompting openai with article info, with traceability
#
# - Each row in the table is an article. Functions can be used to iterate through the table and add additional column.
# - For each prompt, we want to retain the prompt in the table, as well as the message history, and response.

# %%
client = OpenAI()

def print_df(df):
    return tabulate(df, headers='keys', tablefmt='html')

def generate_openai_response_json(prompt, model="gpt-3.5-turbo-1106"):
    """
    Generic function to generate a GPT JSON response
    """
    response = client.chat.completions.create(
    model=model,
    response_format={ "type": "json_object" },
    messages=[
        {"role": "system", "content": "You are a helpful assistant designed to output JSON."},
        {"role": "user", "content": prompt}
    ]
    )
    json_response = response.choices[0].message.content
    return json.loads(json_response)


def generate_openai_response(prompt, model="gpt-3.5-turbo-1106"):
    """
    Generic function to generate a GPT STRING response
    """
    response = client.chat.completions.create(
    model=model,
        messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ]
    )
    return response.choices[0].text



def generate_prompt(query, title, article_text, published_date_str, sentiment_score, sentiment_explanation, negative_claims):
    prompt = f"""
    Task:
    Your task is to review the below article, and its sentiment analysis, to build a case against the article's claims:
    - Provide specific counterpoints to refute the claims of the article.
    - Provide a 'disputability' score, from 0-10, where 10 is most disputable.
    - Provide a list of search queries for additional research you would need to enhance your case.

    Inputs:
    - Search term used to find this article: {query}

    - The article:
    -   Title: {title}
        - Published Date: {published_date_str}
        - Article: {article_text}
    
    - Sentiment Analysis:
        - Sentiment score: {sentiment_score}
        - Sentiment explanation: 
            {sentiment_explanation}
        - Negtive claims: 
            {negative_claims}
    
    ## Outputs
    - Return the output as a JSON object with the following: 
        - 'counter_points': (string with bullet points delimited by new lines), 
        - 'disputability_score': (integer as string from 0-10)
        - 'research_queries': (list of strings)
    
    """
    return prompt


def generate_response(prompt):
    response = generate_openai_response_json(prompt)
    
    return response['counter_points'], response['disputability_score'], response['research_queries']


def apply_response(df, column_names = ['counter_points', 'disputability_score', 'research_queries']):

    df_copy = df.copy()

    new_columns = df_copy.apply(lambda row: generate_response(row['rebuttal_prompt']), axis=1 , result_type='expand')
    new_columns.columns = column_names

    for col in new_columns.columns:
        df_copy.loc[:, col] = new_columns[col].copy()

    return df_copy

# %%
i=0
article_text = df.iloc[i]['article text']
published_date_str = df.iloc[i]['published date str']
title = df.iloc[i]['title']
query = df.iloc[i]['query']
sentiment_score = df.iloc[i]['sentiment_score']
sentiment_explanation = df.iloc[i]['sentiment_explanation']
negative_claims = df.iloc[i]['negative_claims']

prompt = generate_prompt(query, title, article_text, published_date_str, sentiment_score, sentiment_explanation, negative_claims)
display(Markdown(prompt))
# Out:
#     Task:
#     Your task is to review the below article, and its sentiment analysis, to build a case against the article's claims:
#     - Provide specific counterpoints to refute the claims of the article.
#     - Provide a 'disputability' score, from 0-10, where 10 is most disputable.
#     - Provide a list of search queries for additional research you would need to enhance your case.
#
#     Inputs:
#     - Search term used to find this article: Eli Lilly Ozempic Risks
#
#     - The article:
#     -   Title: Intestinal Blockage Added as Potential Ozempic Side Effect - DrugWatch.com
#         - Published Date: 2023-10-04
#         - Article: The U.S. Food and Drug Administration has added ileus, or blocked intestines, to the list of possible adverse reactions to the diabetes medication Ozempic. Other side effects of Ozempic already listed on the label are anaphylaxis, angioedema, rash, urticaria, cholecystitis and cholecystectomy.
#
# Ozempic and similar medications Wegovy and Mounjaro belong to a family of drugs known as GLP-1 agonists. The active ingredient in Ozempic and Wegovy is semaglutide, while Mounjaro contains tirzepatide. Wegovy and Mounjaro already have a warning on their labels about ileus.
#
# Pharmaceutical company Novo Nordisk told CNN in July that GLP-1 agonists have been used for many years and have gone through extensive studies.
#
# “Gastrointestinal (GI) events are well-known side effects of the GLP-1 class,” Novo Nordisk said in a statement. “For semaglutide, the majority of GI side effects are mild to moderate in severity and of short duration. GLP-1’s are known to cause a delay in gastric emptying, as noted in the label of each of our GLP-1 RA medications. Symptoms of delayed gastric emptying, nausea and vomiting are listed as side effects.”
#
# Along with a list of adverse reactions, Ozempic’s label includes this statement: “Because these reactions are reported voluntarily from a population of uncertain size, it is not always possible to reliably estimate their frequency or establish a causal relationship to drug exposure.”
#
# See if You Qualify for a Lawsuit Our Partners Our Trusted Legal Partners Drugwatch partners with trusted law firms to help you take legal action. After submitting the form, one of Drugwatch's partners will contact you for a free case review.
#
# Lawsuits Filed
#
# This labeling change by the FDA comes just weeks after a Louisiana woman filed an Ozempic lawsuit and a Mounjaro lawsuit against drugmakers Novo Nordisk and Eli Lilly. In her suit, Jaclyn Bjorklund said while the manufacturers warned users about other side effects caused by Ozempic they failed to mention the risk of severe gastroparesis.
#
# “Although there is some overlap in the terms, ileus and gastroparesis, they are not synonymous,” FDA spokesperson Chanapa Tantibanchachai said in a statement.
#
# Labels for Ozempic and similar drugs already note that they cause “delay of gastric emptying,” Tantibanchachai said, but the regulator is continuing to monitor “reports of gastroparesis and other related terms” in real-world use of the drug.
#
# “If newly identified safety signals are identified, the FDA will determine what, if any, actions are appropriate after a thorough review of available data,” she said.
#
# Ozempic has recently seen a surge in demand because it may also help people lose weight. According to clinical trials, some of the most common side effects of Ozempic are abdominal pain, constipation, diarrhea, nausea and vomiting. The majority of these side effects should only last a few days or a few weeks. Some of the more serious side effects of Ozempic include:
#
# Acute gallbladder disease
#
# Acute kidney injury
#
# Allergic reactions
#
# Diabetic retinopathy
#
# Hypoglycemia (when used with insulin or sulfonylurea)
#
# Increased risk of thyroid tumors
#
# Pancreatitis
#
# Long-term use of Ozempic may result in chronic side effects, especially gastrointestinal issues. Some people are forced to stop taking the drug because the side effects don’t improve. This could lead to undereating or malabsorption of nutrients.
#
# Ongoing Investigation Into Ozempic
#
# The European Medicines Agency started investigating Ozempic and Wegovy in July after more than 100 reports claiming the drug could cause suicidal thoughts and self-harm. Novo Nordisk released a statement saying “no causal association” between self-harming thoughts and the drugs was found during its own safety monitoring checks.
#
# Wegovy and Saxenda, another medication used to treat diabetes, also have an FDA warning about possible suicidal thoughts. The FDA Adverse Event Reporting System Public Dashboard has at least 60 reports since 2018 of suicidal ideation from people taking semaglutide, the active ingredient in Ozemic and Wegovy.
#
# Popularity for the drug has skyrocketed, with many people using Ozempic for weight loss. Quarterly prescriptions for the drug and similar medications increased by 300% between 2020 and 2022, according to analytics firm Trilliant Health. The drug’s high demand has even caused a global shortage, which is expected to continue well into 2024.
#
#     - Sentiment Analysis:
#         - Sentiment score: 9
#         - Sentiment explanation:
#             The sentiment score is high due to the numerous negative side effects and warnings associated with Ozempic, including the recent addition of intestinal blockage as a potential side effect by the FDA. Additionally, the surge in demand for the drug and the ongoing investigations contribute to the overall negative sentiment.
#         - Negtive claims:
#             - Intestinal blockage (ileus) added as a potential adverse reaction to Ozempic
# - Severe gastroparesis risk not mentioned in warnings
# - Surge in demand for Ozempic causing global shortage
# - Reports of suicidal thoughts and self-harm associated with the drug
# - Adverse side effects such as acute gallbladder disease, acute kidney injury, allergic reactions, diabetic retinopathy, hypoglycemia, increased risk of thyroid tumors, and pancreatitis
#
#     ## Outputs
#     - Return the output as a JSON object with the following:
#         - 'counter_points': (string with bullet points delimited by new lines),
#         - 'disputability_score': (integer as string from 0-10)
#         - 'research_queries': (list of strings)

# %%
prompt
# Out:
# "\n    Task:\n    Your task is to review the below article, and its sentiment analysis, to build a case against the article's claims:\n    - Provide specific counterpoints to refute the claims of the article.\n    - Provide a 'disputability' score, from 0-10, where 10 is most disputable.\n    - Provide a list of search queries for additional research you would need to enhance your case.\n\n    Inputs:\n    - Search term used to find this article: Eli Lilly Ozempic Risks\n\n    - The article:\n    -   Title: Intestinal Blockage Added as Potential Ozempic Side Effect - DrugWatch.com\n        - Published Date: 2023-10-04\n        - Article: The U.S. Food and Drug Administration has added ileus, or blocked intestines, to the list of possible adverse reactions to the diabetes medication Ozempic. Other side effects of Ozempic already listed on the label are anaphylaxis, angioedema, rash, urticaria, cholecystitis and cholecystectomy.\n\nOzempic and similar medications Wegovy and Mounjaro belong to a family of drugs known as GLP-1 agonists. The active ingredient in Ozempic and Wegovy is semaglutide, while Mounjaro contains tirzepatide. Wegovy and Mounjaro already have a warning on their labels about ileus.\n\nPharmaceutical company Novo Nordisk told CNN in July that GLP-1 agonists have been used for many years and have gone through extensive studies.\n\n“Gastrointestinal (GI) events are well-known side effects of the GLP-1 class,” Novo Nordisk said in a statement. “For semaglutide, the majority of GI side effects are mild to moderate in severity and of short duration. GLP-1’s are known to cause a delay in gastric emptying, as noted in the label of each of our GLP-1 RA medications. Symptoms of delayed gastric emptying, nausea and vomiting are listed as side effects.”\n\nAlong with a list of adverse reactions, Ozempic’s label includes this statement: “Because these reactions are reported voluntarily from a population of uncertain size, it is not always possible to reliably estimate their frequency or establish a causal relationship to drug exposure.”\n\nSee if You Qualify for a Lawsuit Our Partners Our Trusted Legal Partners Drugwatch partners with trusted law firms to help you take legal action. After submitting the form, one of Drugwatch's partners will contact you for a free case review.\n\nLawsuits Filed\n\nThis labeling change by the FDA comes just weeks after a Louisiana woman filed an Ozempic lawsuit and a Mounjaro lawsuit against drugmakers Novo Nordisk and Eli Lilly. In her suit, Jaclyn Bjorklund said while the manufacturers warned users about other side effects caused by Ozempic they failed to mention the risk of severe gastroparesis.\n\n“Although there is some overlap in the terms, ileus and gastroparesis, they are not synonymous,” FDA spokesperson Chanapa Tantibanchachai said in a statement.\n\nLabels for Ozempic and similar drugs already note that they cause “delay of gastric emptying,” Tantibanchachai said, but the regulator is continuing to monitor “reports of gastroparesis and other related terms” in real-world use of the drug.\n\n“If newly identified safety signals are identified, the FDA will determine what, if any, actions are appropriate after a thorough review of available data,” she said.\n\nOzempic has recently seen a surge in demand because it may also help people lose weight. According to clinical trials, some of the most common side effects of Ozempic are abdominal pain, constipation, diarrhea, nausea and vomiting. The majority of these side effects should only last a few days or a few weeks. Some of the more serious side effects of Ozempic include:\n\nAcute gallbladder disease\n\nAcute kidney injury\n\nAllergic reactions\n\nDiabetic retinopathy\n\nHypoglycemia (when used with insulin or sulfonylurea)\n\nIncreased risk of thyroid tumors\n\nPancreatitis\n\nLong-term use of Ozempic may result in chronic side effects, especially gastrointestinal issues. Some people are forced to stop taking the drug because the si ...

# %%
counter_points, disputability_score, research_queries = generate_response(prompt)

output = f""" 

Negative claims: 
    \n{negative_claims}

Counter points: 
    \n{counter_points}

Disputability score: {disputability_score}

Research queries: {research_queries}

"""

display(Markdown(output))
# Out:
#
#
# Negative claims:
#
# - Intestinal blockage (ileus) added as a potential adverse reaction to Ozempic
# - Severe gastroparesis risk not mentioned in warnings
# - Surge in demand for Ozempic causing global shortage
# - Reports of suicidal thoughts and self-harm associated with the drug
# - Adverse side effects such as acute gallbladder disease, acute kidney injury, allergic reactions, diabetic retinopathy, hypoglycemia, increased risk of thyroid tumors, and pancreatitis
#
# Counter points:
#
# 1. The pharmaceutical company, Novo Nordisk, states that gastrointestinal events are well-known side effects of GLP-1 class and that the majority of these side effects are mild to moderate and of short duration. 2. The FDA continuously monitors safety signals and will take appropriate actions based on available data. 3. The reports of suicidal thoughts and self-harm associated with the drug have been investigated by Novo Nordisk and no causal association was found. 4. The surge in demand and global shortage may be attributed to the drug's potential for weight loss, which could be a positive indication for its use.
#
# Disputability score: 7
#
# Research queries: ['Long-term studies on the safety and efficacy of Ozempic and similar GLP-1 agonists', 'Comparison of reported adverse effects between Ozempic and other diabetes medications', "FDA's monitoring and assessment process for labeling changes and side effect reports", 'Clinical trials and real-world data on the efficacy and safety of Ozempic for weight loss']

# %%
df['rebuttal_prompt'] = df.apply(lambda row: generate_prompt(row['query'], row['title'], row['article text'], row['published date str'], row['query'], row['sentiment_explanation'], row['negative_claims'] ), axis=1)

# %%
df = df.sort_values(by=['sentiment_score'], ascending=False)
df = df.head(50)

# %%
# df

# %%
df = apply_response(df)

# %%
df = df.sort_values(by=['disputability_score'], ascending=False)

# %%
df.columns
# Out:
# Index(['title', 'description', 'published date', 'url', 'publisher', 'query',
#        'query end date', 'published datetime', 'published date str',
#        'article text', 'article html', 'article summary', 'article keywords',
#        'sentiment_prompt', 'sentiment_score', 'sentiment_explanation',
#        'negative_claims', '__index_level_0__', 'rebuttal_prompt',
#        'counter_points', 'disputability_score', 'research_queries'],
#       dtype='object')

# %%
df
# Out:
#                                                 title  \
# 41  Diabetes drug Mounjaro helped dieters shed 60 ...
# 61  Mounjaro vs. Insulin: Which Is More Effective ...
# 54  US FDA approves Jardiance® for the treatment o...
# 21  Ozempic and other weight-loss drugs will power...
# 24               Should We End Obesity? | TIME - TIME
# 12  Florida pharmacies selling GLP-1 knockoffs fac...
# 69  1 Big Risk Facing Ozempic, Wegovy, and Other G...
# 64  Doctors raise cost, coverage concerns over new...
# 44  Weight-loss drugs are impacting everything fro...
# 43  How does the weight loss drug Zepbound compare...
# 36  Behold the Ozempic effect on business - Financ...
# 34  Makers of Ozempic, Mounjaro race to ramp up su...
# 26  Is Ozempic a danger to the McDonald's share pr...
# 13  The rationing of popular weight-loss drugs Oze...
# 16  Ozempic Pills for Weight Loss Don't Reduce Pri...
# 18  New study ties weight-loss drugs Wegovy, Ozemp...
# 19  Wall Street Breakfast Podcast: Walmart Links O...
# 22  Eli Lilly says weight loss drug Zepbound is no...
# 15  Eli Lilly Seeks Diabetes Drug Lawsuit Dismissa...
# 38  Mounjaro Lawsuit: Eli Lilly Low-Grade Mounjaro...
# 7   Can Ozempic, Wegovy Treat Alcoholism? - Bloomberg
# 11  Pfizer struggles to catch up to Ozempic, Wegov...
# 49  Ozempic shortage expected to last into 2024: H...
# 2   Mounjaro Lawsuits - Lawsuit Information Center...
# 46  Weight-loss drugs like Ozempic and Wegovy may ...
# 51  Zepbound is Eli Lilly’s new weight loss drug: ...
# 9   Diabetes Weight Loss Drugs Lawsuits - The Lega...
# 40  Popular Weight-Loss Drugs Come with Side Effec...
# 42  For Weight Loss and Blood Sugar, Mounjaro May ...
# 63  Eli Lilly sues clinics allegedly selling knock...
# 39  Could Ozempic Harm These 3 Medical Device Stoc...
# 3   What's the Ozempic effect on the stock market?...
# 8   Woman dies after taking Ozempic to slim down f...
# 10  Diabetes Drugs Used for Weight Loss Could Caus...
# 28  Beyond obesity care: Flood of popular weight l...
# 17  Ozempic, Wegovy linked to severe medical condi...
# 47  Eli Lilly Files Lawsuits Against Clinics Selli...
# 30  Roche Chases Novo's Ozempic, Wegovy With $3 Bi...
# 33  2 Reasons Why Eli Lilly's Mounjaro Might Beat ...
# 20  These diabetes stocks, pummeled by the Ozempic...
# 14  Microbial Contaminant Control Problems at Ozem...
# 23  FDA adds warning for intestinal blockage on No...
# 29  Ozempic and Wegovy Don't Cost What You Think T...
# 31  Tiktok's Fueling Demand for Weight Loss Drugs ...
# 35  Pfizer Struggles To Catch Up To Ozempic, Wegov...
# 32  Study shows Novo's Ozempic, Wegovy pose risk o...
# 1   Ozempic, Wegovy, and other weight loss drugs' ...
# 6   Anti-obesity drugs' side effects: what we know...
# 27  Lilly (LLY) Up on NVO's Ozempic Early Success ...
# 0   Intestinal Blockage Added as Potential Ozempic...
#
#                                           description published date  \
# 41  Diabetes drug Mounjaro helped dieters shed 60 ...     2023-10-15
# 61  Mounjaro vs. Insulin: Which Is More Effective ...     2023-10-03
# 54  US FDA approves Jardiance® for the treatment o...     2023-09-22
# 21  Ozempic and other weight-loss drugs will power...     2023-11-04
# 24                Should We End Obesity? | TIME  TIME     2023-11-08
# 12  Florida pharmacies selling GLP-1 knockoffs fac...     2023-11-30
# 69  1 Big Risk Facing Ozempic, Wegovy, and Other G...     2023-10-14
# 64  Doctors raise cost, coverage concerns over new...     2023-09-19
# 44  Weight-loss drugs are impacting everything fro...     2023-11-13
# 43  How does the weight loss drug Zepbound compare...     2023-11-13
# 36  Behold the Ozempic effect on business  Financi...     2023-11-19
# 34  Makers of Ozempic, Mounjaro race to ramp up su...     2023-10-06
# 26  Is Ozempic a danger to the McDonald's share pr...     2023-10-29
# 13  The rationing of popular weight-loss drugs Oze...     2023-11-15
# 16  Ozempic Pills for Weight Loss Don't Reduce Pri...     2023-11-17
# 18  New study ties weight-loss drugs Wegovy, Ozemp...     2023-10-05
# 19  Wall Street Breakfast Podcast: Walmart Links O...     2023-10-05
# 22  Eli Lilly says weight loss drug Zepbound is no...     2023-12-06
# 15  Eli Lilly Seeks Diabetes Drug Lawsuit Dismissa...     2023-11-17
# 38  Mounjaro Lawsuit: Eli Lilly Low-Grade Mounjaro...     2023-10-10
# 7    Can Ozempic, Wegovy Treat Alcoholism?  Bloomberg     2023-12-08
# 11  Pfizer struggles to catch up to Ozempic, Wegov...     2023-12-02
# 49  Ozempic shortage expected to last into 2024: H...     2023-12-07
# 2   Mounjaro Lawsuits  Lawsuit Information Center ...     2023-10-31
# 46  Weight-loss drugs like Ozempic and Wegovy may ...     2023-09-27
# 51  Zepbound is Eli Lilly’s new weight loss drug: ...     2023-11-09
# 9   Diabetes Weight Loss Drugs Lawsuits  The Legal...     2023-10-27
# 40  Popular Weight-Loss Drugs Come with Side Effec...     2023-10-19
# 42  For Weight Loss and Blood Sugar, Mounjaro May ...     2023-09-26
# 63  Eli Lilly sues clinics allegedly selling knock...     2023-09-19
# 39  Could Ozempic Harm These 3 Medical Device Stoc...     2023-11-25
# 3   What's the Ozempic effect on the stock market?...     2023-11-11
# 8   Woman dies after taking Ozempic to slim down f...     2023-11-06
# 10  Diabetes Drugs Used for Weight Loss Could Caus...     2023-10-27
# 28  Beyond obesity care: Flood of popular weight l...     2023-09-16
# 17  Ozempic, Wegovy linked to severe medical condi...     2023-10-05
# 47  Eli Lilly Files Lawsuits Against Clinics Selli...     2023-09-27
# 30  Roche Chases Novo's Ozempic, Wegovy With $3 Bi...     2023-12-04
# 33  2 Reasons Why Eli Lilly's Mounjaro Might Beat ...     2023-10-06
# 20  These diabetes stocks, pummeled by the Ozempic...     2023-10-05
# 14  Microbial Contaminant Control Problems at Ozem...     2023-09-20
# 23  FDA adds warning for intestinal blockage on No...     2023-09-28
# 29  Ozempic and Wegovy Don't Cost What You Think T...     2023-10-22
# 31  Tiktok's Fueling Demand for Weight Loss Drugs ...     2023-11-27
# 35  Pfizer Struggles To Catch Up To Ozempic, Wegov...     2023-12-01
# 32  Study shows Novo's Ozempic, Wegovy pose risk o...     2023-10-06
# 1   Ozempic, Wegovy, and other weight loss drugs' ...     2023-10-31
# 6   Anti-obesity drugs' side effects: what we know...     2023-10-13
# 27  Lilly (LLY) Up on NVO's Ozempic Early Success ...     2023-10-12
# 0   Intestinal Blockage Added as Potential Ozempic...     2023-10-04
#
#                                                   url  \
# 41  https://news.google.com/rss/articles/CBMihQFod...
# 61  https://news.google.com/rss/articles/CBMid2h0d...
# 54  https://news.google.com/rss/articles/CBMieGh0d...
# 21  https://news.google.com/rss/articles/CBMiTWh0d...
# 24  https://news.google.com/rss/articles/CBMiOWh0d...
# 12  https://news.google.com/rss/articles/CBMif2h0d...
# 69  https://news.google.com/rss/articles/CBMiW2h0d...
# 64  https://news.google.com/rss/articles/CBMie2h0d...
# 44  https://news.google.com/rss/articles/CBMiZ2h0d...
# 43  https://news.google.com/rss/articles/CBMiXWh0d...
# 36  https://news.google.com/rss/articles/CBMiP2h0d...
# 34  https://news.google.com/rss/articles/CBMiSGh0d...
# 26  https://news.google.com/rss/articles/CBMiVGh0d...
# 13  https://news.google.com/rss/articles/CBMiQ2h0d...
# 16  https://news.google.com/rss/articles/CBMicGh0d...
# 18  https://news.google.com/rss/articles/CBMiPWh0d...
# 19  https://news.google.com/rss/articles/CBMiZWh0d...
# 22  https://news.google.com/rss/articles/CBMiZ2h0d...
# 15  https://news.google.com/rss/articles/CBMiU2h0d...
# 38  https://news.google.com/rss/articles/CBMiMWh0d...
# 7   https://news.google.com/rss/articles/CBMiWWh0d...
# 11  https://news.google.com/rss/articles/CBMidmh0d...
# 49  https://news.google.com/rss/articles/CBMimwFod...
# 2   https://news.google.com/rss/articles/CBMiQGh0d...
# 46  https://news.google.com/rss/articles/CBMiXmh0d...
# 51  https://news.google.com/rss/articles/CBMiZmh0d...
# 9   https://news.google.com/rss/articles/CBMiaGh0d...
# 40  https://news.google.com/rss/articles/CBMiXGh0d...
# 42  https://news.google.com/rss/articles/CBMib2h0d...
# 63  https://news.google.com/rss/articles/CBMia2h0d...
# 39  https://news.google.com/rss/articles/CBMiW2h0d...
# 3   https://news.google.com/rss/articles/CBMieWh0d...
# 8   https://news.google.com/rss/articles/CBMiYWh0d...
# 10  https://news.google.com/rss/articles/CBMipQFod...
# 28  https://news.google.com/rss/articles/CBMijAFod...
# 17  https://news.google.com/rss/articles/CBMifGh0d...
# 47  https://news.google.com/rss/articles/CBMieGh0d...
# 30  https://news.google.com/rss/articles/CBMibGh0d...
# 33  https://news.google.com/rss/articles/CBMiW2h0d...
# 20  https://news.google.com/rss/articles/CBMikAFod...
# 14  https://news.google.com/rss/articles/CBMiXGh0d...
# 23  https://news.google.com/rss/articles/CBMiaWh0d...
# 29  https://news.google.com/rss/articles/CBMiSGh0d...
# 31  https://news.google.com/rss/articles/CBMif2h0d...
# 35  https://news.google.com/rss/articles/CBMiemh0d...
# 32  https://news.google.com/rss/articles/CBMifWh0d...
# 1   https://news.google.com/rss/articles/CBMibWh0d...
# 6   https://news.google.com/rss/articles/CBMiMmh0d...
# 27  https://news.google.com/rss/articles/CBMiSmh0d...
# 0   https://news.google.com/rss/articles/CBMiUmh0d...
#
#                                             publisher  \
# 41  {'href': 'https://www.nbcchicago.com', 'title'...
# 61  {'href': 'https://www.healthline.com', 'title'...
# 54  {'href': 'https://investor.lilly.com', 'title'...
# 21  {'href': 'https://finance.yahoo.com', 'title':...
# 24      {'href': 'https://time.com', 'title': 'TIME'}
# 12  {'href': 'https://www.fiercepharma.com', 'titl...
# 69  {'href': 'https://www.fool.com', 'title': 'The...
# 64  {'href': 'https://www.fiercepharma.com', 'titl...
# 44  {'href': 'https://fortune.com', 'title': 'Fort...
# 43  {'href': 'https://www.uchealth.org', 'title': ...
# 36  {'href': 'https://www.ft.com', 'title': 'Finan...
# 34    {'href': 'https://www.cnn.com', 'title': 'CNN'}
# 26  {'href': 'https://uk.finance.yahoo.com', 'titl...
# 13  {'href': 'https://www.politico.com', 'title': ...
# 16  {'href': 'https://www.bloomberg.com', 'title':...
# 18  {'href': 'https://www.cbc.ca', 'title': 'CBC N...
# 19  {'href': 'https://seekingalpha.com', 'title': ...
# 22  {'href': 'https://www.wxyz.com', 'title': 'WXY...
# 15  {'href': 'https://medtruth.com', 'title': 'Med...
# 38  {'href': 'https://www.drugwatch.com', 'title':...
# 7   {'href': 'https://www.bloomberg.com', 'title':...
# 11  {'href': 'https://www.latimes.com', 'title': '...
# 49  {'href': 'https://www.cp24.com', 'title': 'CP24'}
# 2   {'href': 'https://www.lawsuit-information-cent...
# 46  {'href': 'https://fortune.com', 'title': 'Fort...
# 51  {'href': 'https://www.nbcnews.com', 'title': '...
# 9   {'href': 'https://www.legalexaminer.com', 'tit...
# 40  {'href': 'https://www.scientificamerican.com',...
# 42  {'href': 'https://www.healthline.com', 'title'...
# 63  {'href': 'https://www.cnbc.com', 'title': 'CNBC'}
# 39  {'href': 'https://www.fool.com', 'title': 'The...
# 3   {'href': 'https://www.theglobeandmail.com', 't...
# 8   {'href': 'https://nypost.com', 'title': 'New Y...
# 10  {'href': 'https://www.legalexaminer.com', 'tit...
# 28  {'href': 'https://www.healio.com', 'title': 'H...
# 17  {'href': 'https://www.nbcnews.com', 'title': '...
# 47  {'href': 'https://www.healthline.com', 'title'...
# 30  {'href': 'https://www.bloomberg.com', 'title':...
# 33  {'href': 'https://www.fool.com', 'title': 'The...
# 20  {'href': 'https://www.morningstar.com', 'title...
# 14  {'href': 'https://www.aboutlawsuits.com', 'tit...
# 23  {'href': 'https://www.fiercepharma.com', 'titl...
# 29  {'href': 'https://www.nytimes.com', 'title': '...
# 31  {'href': 'https://www.bloomberg.com', 'title':...
# 35  {'href': 'https://www.bloomberg.com', 'title':...
# 32  {'href': 'https://www.fiercepharma.com', 'titl...
# 1   {'href': 'https://finance.yahoo.com', 'title':...
# 6   {'href': 'https://www.nature.com', 'title': 'N...
# 27  {'href': 'https://finance.yahoo.com', 'title':...
# 0   {'href': 'https://www.drugwatch.com', 'title':...
#
#                       query             query end date  published datetime  \
# 41  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-15 07:00:00
# 61  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-03 07:00:00
# 54  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-09-22 07:00:00
# 21  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-04 07:00:00
# 24  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-08 08:00:00
# 12  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-30 08:00:00
# 69  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-14 07:00:00
# 64  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-09-19 07:00:00
# 44  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-13 08:00:00
# 43  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-13 08:00:00
# 36  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-19 08:00:00
# 34  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-06 07:00:00
# 26  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-29 07:00:00
# 13  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-15 08:00:00
# 16  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-17 08:00:00
# 18  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-05 07:00:00
# 19  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-05 07:00:00
# 22  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-12-06 20:42:50
# 15  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-17 08:00:00
# 38  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-10 06:49:14
# 7   Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-12-08 11:00:11
# 11  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-12-02 08:00:00
# 49  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-12-07 00:39:37
# 2   Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-31 07:00:00
# 46  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-09-27 07:00:00
# 51  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-09 08:00:00
# 9   Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-27 07:00:00
# 40  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-19 07:00:00
# 42  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-09-26 07:00:00
# 63  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-09-19 07:00:00
# 39  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-25 08:00:00
# 3   Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-11 08:00:00
# 8   Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-06 08:00:00
# 10  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-27 07:00:00
# 28  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-09-16 07:00:00
# 17  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-05 07:00:00
# 47  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-09-27 07:00:00
# 30  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-12-04 12:45:29
# 33  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-06 07:00:00
# 20  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-05 07:00:00
# 14  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-09-20 07:00:00
# 23  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-09-28 07:00:00
# 29  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-22 07:00:00
# 31  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-27 08:00:00
# 35  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-12-01 08:00:00
# 32  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-06 07:00:00
# 1   Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-31 07:00:00
# 6   Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-13 07:00:00
# 27  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-12 07:00:00
# 0   Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-04 07:00:00
#
#    published date str                                       article text  ...  \
# 41         2023-10-15  The medicine in the diabetes drug Mounjaro hel...  ...
# 61         2023-10-03  Share on Pinterest Mounjaro appears to be a sa...  ...
# 54         2023-09-22  Approval adds to the treatment options for the...  ...
# 21         2023-11-04  Weight-loss drugs could fuel huge gains for th...  ...
# 24         2023-11-08  It’s unusual for a medication to become a hous...  ...
# 12         2023-11-30  Seven weeks after a federal judge dismissed (P...  ...
# 69         2023-10-14  Weight-loss drugs have been soaring in popular...  ...
# 64         2023-09-19  A survey of 100 doctors in the U.S. who prescr...  ...
# 44         2023-11-13  U.S. companies across sectors such as food and...  ...
# 43         2023-11-13  The new weight loss drug, Zepbound, and other ...  ...
# 36         2023-11-19  Cookies on FT Sites\n\nWe use cookies and othe...  ...
# 34         2023-10-06  CNN —\n\nAt Dr. Louis Aronne’s weight loss cen...  ...
# 26         2023-10-29  Image source: Getty Images\n\nThe McDonald’s (...  ...
# 13         2023-11-15  Since July, state health plan members seeking ...  ...
# 16         2023-11-17  Novo Nordisk A/S and Eli Lilly & Co. are touti...  ...
# 18         2023-10-05  Medicines in the same class as Novo Nordisk's ...  ...
# 19         2023-10-05  Justin Sullivan\n\nListen below or on the go o...  ...
# 22         2023-12-06  (WXYZ) — In today’s Health Alert, the eagerly ...  ...
# 15         2023-11-17  Pharmaceutical company Eli Lilly is seeking to...  ...
# 38         2023-10-10  If you developed severe gastroparesis, ileus o...  ...
# 7          2023-12-08  Bloomberg Markets China Open\n\nBloomberg Mark...  ...
# 11         2023-12-02  On Friday, Pfizer announced that it’s dropping...  ...
# 49         2023-12-07  \n\nThe Canadian Press\n\n\n\n\n\nHealth Canad...  ...
# 2          2023-10-31  Mounjaro is a diabetes drug manufactured by El...  ...
# 46         2023-09-27  It may come as a surprise, but not all weight ...  ...
# 51         2023-11-09  A new weight loss drug has been approved that ...  ...
# 9          2023-10-27  About Diabetes Weight Loss Drugs\n\nThe use of...  ...
# 40         2023-10-19  The treatment of obesity has been revolutioniz...  ...
# 42         2023-09-26  Share on Pinterest An analysis of 22 studies c...  ...
# 63         2023-09-19  A pharmacist displays boxes of Ozempic, a sema...  ...
# 39         2023-11-25  Ozempic, Novo Nordisk's (NVO -0.46%) blockbust...  ...
# 3          2023-11-11  Open this photo in gallery: The logo of Danish...  ...
# 8          2023-11-06  An Australian woman who took Ozempic to shed a...  ...
# 10         2023-10-27  For decades, consumers have been chasing after...  ...
# 28         2023-09-16  Save\n\nBeyond obesity care: Flood of popular ...  ...
# 17         2023-10-05  People who take popular drugs for weight loss,...  ...
# 47         2023-09-27  Share on Pinterest Eli Lilly, maker of the Oze...  ...
# 30         2023-12-04  Bloomberg Markets China Open\n\nBloomberg Mark...  ...
# 33         2023-10-06  Much like Novo Nordisk's (NVO -0.46%) money-ge...  ...
# 20         2023-10-05  By Eleanor Laise\n\nDexCom could be the first ...  ...
# 14         2023-09-20  Ozempic (semaglutide) was originally approved ...  ...
# 23         2023-09-28  While GLP-1 drugs from Novo Nordisk and Eli Li...  ...
# 29         2023-10-22  The problem is daunting: Powerful but expensiv...  ...
# 31         2023-11-27  Weight-loss drugs are everywhere these days. A...  ...
# 35         2023-12-01  On Friday, Pfizer Inc. announced that it’s dro...  ...
# 32         2023-10-06  People who use Novo Nordisk’s popular weight-l...  ...
# 1          2023-10-31  Weight loss and diabetes drugs — a potential $...  ...
# 6          2023-10-13  NEWS EXPLAINER\n\n13 October 2023 Anti-obesity...  ...
# 27         2023-10-12  Shares of Eli Lilly and Company LLY were up al...  ...
# 0          2023-10-04  The U.S. Food and Drug Administration has adde...  ...
#
#                                      article keywords  \
# 41  [drug, shed, weight, finds, dieters, helped, t...
# 61  [trial, group, fastacting, weight, insulin, vs...
# 54  [disease, adults, risk, fda, approves, blood, ...
# 21  [gains, drugs, power, weight, ozempic, billion...
# 24  [disease, health, weight, ozempic, end, patien...
# 12  [drugs, versions, lawsuits, companies, knockof...
# 69  [drugs, risk, effects, weight, company, ozempi...
# 64  [suffer, issues, weight, semaglutide, poor, no...
# 44  [drugs, impacting, surgery, weight, impact, sn...
# 43  [drug, drugs, weight, ozempic, zepbound, work,...
# 36  [reasons, reliable, ozempic, secure, ft, socia...
# 34  [drugs, medicines, weight, ozempic, supply, ra...
# 26  [ozempic, motley, fool, danger, mcdonalds, thr...
# 13  [rationing, drugs, health, weight, state, stat...
# 16  [drugs, effects, sold, issues, versions, table...
# 18  [drugs, ties, serious, conditions, risk, drug,...
# 19  [drugs, street, podcast, weight, 03, company, ...
# 22  [drug, weight, eli, doses, zepbound, youre, pa...
# 15  [drug, warning, eli, claims, diabetes, label, ...
# 38  [updates, lawsuits, lowgrade, eli, attorney, g...
# 7   [drinking, china, trading, open, latest, stop,...
# 11  [struggles, drugs, weight, catch, rival, pills...
# 49  [drugs, health, yearit, canada, 2024, expectin...
# 2   [drug, weight, lawsuits, ozempic, cases, gallb...
# 46  [weight, muscle, loss, say, older, adults, fat...
# 51  [drug, lillys, effects, know, weight, eli, zep...
# 9   [drugs, effects, lawsuits, weight, medications...
# 40  [drugs, effects, weight, semaglutide, medicati...
# 42  [drugs, drug, weight, blood, semaglutide, dose...
# 63  [drug, drugs, versions, eli, selling, ozempic,...
# 39  [medicines, segment, device, surgery, cardiova...
# 3   [drugs, drug, stock, investors, companies, oze...
# 8   [60, drug, dies, shouldnt, taking, gone, woman...
# 10  [drugs, effects, type, issues, weight, cause, ...
# 28  [weight, semaglutide, novo, loss, flood, opens...
# 17  [drugs, drug, risk, weight, finds, medications...
# 47  [drug, drugs, versions, lawsuits, fda, eli, se...
# 30  [drugs, cant, investors, china, trading, open,...
# 33  [drug, lillys, weight, eli, reasons, ozempic, ...
# 20  [bargains, device, look, pummeled, insulin, oz...
# 14  [weight, control, novo, users, loss, stomach, ...
# 23  [risk, flagging, ileus, update, fda, intestina...
# 29  [drugs, health, generally, companies, willett,...
# 31  [drugs, lillys, drug, hit, ozempic, zepbound, ...
# 35  [drugs, weight, gold, rival, ozempic, zepbound...
# 32  [drugs, risk, pose, small, semaglutide, study,...
# 1   [drugs, told, health, weight, impact, business...
# 6   [drugs, effects, m, far, know, j, med, semaglu...
# 27  [stock, lly, company, early, ii, ozempic, succ...
# 0   [blockage, effects, drug, fda, intestinal, weg...
#
#                                      sentiment_prompt sentiment_score  \
# 41  \n    - Your task is to read the article below...               7
# 61  \n    - Your task is to read the article below...               8
# 54  \n    - Your task is to read the article below...               8
# 21  \n    - Your task is to read the article below...               8
# 24  \n    - Your task is to read the article below...               8
# 12  \n    - Your task is to read the article below...               9
# 69  \n    - Your task is to read the article below...               7
# 64  \n    - Your task is to read the article below...               7
# 44  \n    - Your task is to read the article below...               8
# 43  \n    - Your task is to read the article below...               8
# 36  \n    - Your task is to read the article below...               8
# 34  \n    - Your task is to read the article below...               8
# 26  \n    - Your task is to read the article below...               8
# 13  \n    - Your task is to read the article below...               9
# 16  \n    - Your task is to read the article below...               9
# 18  \n    - Your task is to read the article below...               9
# 19  \n    - Your task is to read the article below...               8
# 22  \n    - Your task is to read the article below...               9
# 15  \n    - Your task is to read the article below...               9
# 38  \n    - Your task is to read the article below...               9
# 7   \n    - Your task is to read the article below...               9
# 11  \n    - Your task is to read the article below...               9
# 49  \n    - Your task is to read the article below...               8
# 2   \n    - Your task is to read the article below...               9
# 46  \n    - Your task is to read the article below...               8
# 51  \n    - Your task is to read the article below...               8
# 9   \n    - Your task is to read the article below...               9
# 40  \n    - Your task is to read the article below...               8
# 42  \n    - Your task is to read the article below...               8
# 63  \n    - Your task is to read the article below...               8
# 39  \n    - Your task is to read the article below...               8
# 3   \n    - Your task is to read the article below...               9
# 8   \n    - Your task is to read the article below...               9
# 10  \n    - Your task is to read the article below...               9
# 28  \n    - Your task is to read the article below...               9
# 17  \n    - Your task is to read the article below...               9
# 47  \n    - Your task is to read the article below...               8
# 30  \n    - Your task is to read the article below...               8
# 33  \n    - Your task is to read the article below...               8
# 20  \n    - Your task is to read the article below...               8
# 14  \n    - Your task is to read the article below...               9
# 23  \n    - Your task is to read the article below...               8
# 29  \n    - Your task is to read the article below...               8
# 31  \n    - Your task is to read the article below...               8
# 35  \n    - Your task is to read the article below...               8
# 32  \n    - Your task is to read the article below...               9
# 1   \n    - Your task is to read the article below...               9
# 6   \n    - Your task is to read the article below...               9
# 27  \n    - Your task is to read the article below...               8
# 0   \n    - Your task is to read the article below...               9
#
#                                 sentiment_explanation  \
# 41  The sentiment score of 7 is given because the ...
# 61  The sentiment negativity score is 8 because th...
# 54  The sentiment score is given an 8 out of 10 du...
# 21  The sentiment score is given as 8 due to the f...
# 24  The sentiment negativity score of 8 is given d...
# 12  The sentiment score is given a 9 because the a...
# 69  The sentiment negativity score is 7 because th...
# 64  The sentiment negativity score is 7 because th...
# 44  The sentiment score is 8 because the article d...
# 43  The sentiment score is given as 8 due to the n...
# 36  The sentiment score is given as 8 due to the a...
# 34  The sentiment score is high because the articl...
# 26  The sentiment negativity score is high due to ...
# 13  The article expresses strong negative sentimen...
# 16  The sentiment score is 9 due to the negative t...
# 18  The sentiment negativity score is given as 9 d...
# 19  The sentiment score is relatively high due to ...
# 22  The sentiment score is 9 due to the numerous p...
# 15  The sentiment score is given a 9 due to the st...
# 38  The sentiment score is 9 because the article p...
# 7   The sentiment negativity score is 9 because th...
# 11  The article overall portrays a very negative s...
# 49  The sentiment negativity score is 8, indicatin...
# 2   The sentiment score is 9 because the article d...
# 46  The sentiment negativity score is 8 due to the...
# 51  The sentiment score is 8 because the article h...
# 9   The sentiment score of 9 is given due to the n...
# 40  The sentiment score is 8 because the article h...
# 42  The sentiment score is given an 8 due to the n...
# 63  The sentiment score is given as 8 due to the n...
# 39  The sentiment negativity score is 8 because th...
# 3   The sentiment negativity score is 9 due to the...
# 8   The sentiment score is given a high rating due...
# 10  The sentiment towards Eli Lilly Ozempic and si...
# 28  The sentiment score is high due to numerous ne...
# 17  The sentiment score is given a 9 due to the si...
# 47  The sentiment negativity score is 8 because th...
# 30  The sentiment score is 8 because the article d...
# 33  The sentiment negativity score is 8 because th...
# 20  The sentiment negativity score is 8 because th...
# 14  The sentiment score is given a 9 due to the nu...
# 23  The sentiment negativity score is 8 due to the...
# 29  The sentiment score is 8 because the article h...
# 31  The sentiment negativity score is high because...
# 35  The sentiment negativity score of 8 is given b...
# 32  The sentiment score is 9 because the article h...
# 1   The article portrays a highly negative sentime...
# 6   The sentiment score is given a 9 because the a...
# 27  The sentiment score is 8 out of 10 as the arti...
# 0   The sentiment score is high due to the numerou...
#
#                                       negative_claims __index_level_0__  \
# 41  - Side effects including nausea, diarrhea, and...                20
# 61   - Mounjaro showed significantly fewer instanc...                73
# 54  - Jardiance is not recommended for use to impr...                32
# 21  - The article lacks critical discussion about ...                51
# 24  - The widespread use and marketing of Ozempic ...                16
# 12  - Novo Nordisk alleges that Brooksville Pharma...                52
# 69  - Ozempic and other GLP-1 receptor agonists ma...                35
# 64  - Doctors have significant concerns about the ...                30
# 44  - Retailers and food/beverage companies are co...                12
# 43  - Zepbound and other weight loss drugs have hi...                11
# 36  - The article highlights potential health risk...                 9
# 34  - The demand for Eli Lilly's medicines, especi...                 4
# 26  - GLP-1 weight-loss drugs like Ozempic and Weg...                50
# 13  - State health plans imposing clinical lifesty...                57
# 16  - Obesity pills under development have major s...                68
# 18  - Medications in the same class as Wegovy and ...                26
# 19  Walmart reports a slight pullback in overall b...                28
# 22  - Zepbound may cause tumors in the thyroid, in...                43
# 15   - Eli Lilly seeking dismissal of lawsuit file...                67
# 38  - Mounjaro and Ozempic are alleged to cause se...                60
# 7   The article does not mention specific negative...                65
# 11  - Pfizer's experimental weight-loss pill cause...                58
# 49  - Worldwide shortage of diabetes drugs, includ...                64
# 2   - Using higher doses of Mounjaro for weight lo...                46
# 46  - Weight-loss drugs like Ozempic and Wegovy ma...                 7
# 51  - The high cost of Zepbound may be a barrier f...                17
# 9   - Massive shortages of diabetes medications fo...                70
# 40   - Increased incidence of pancreatitis and gas...                61
# 42  - Mounjaro (Tirzepatide) was found to be super...                23
# 63  - Eli Lilly suing medical spas, wellness clini...                29
# 39  - The article suggests that the popularity of ...                36
# 3   - Excessive speculation and irrational exubera...                 1
# 8   - An Australian woman died from gastrointestin...                62
# 10  - Ozempic and similar diabetes drugs used for ...                71
# 28  - Lawsuit alleging Novo Nordisk and Eli Lilly ...                75
# 17  - Research published in the Journal of the Ame...                25
# 47  - Compounded medications do not have the same ...                 6
# 30  The article does not contain specific negative...                55
# 33  - Mounjaro appears to be more effective at con...                 5
# 20  - Diabetes device stocks have been crushed by ...                27
# 14  - Increasing evidence of serious risk of stoma...                63
# 23  - The FDA has updated the label for Novo’s Oze...                14
# 29       - Expensive cost of Ozempic and Wegovy drugs                56
# 31  - Ads, pop culture, and social media have cont...                48
# 35  - Pfizer dropping development of an experiment...                44
# 32  - Novo's popular GLP-1 products are linked to ...                 3
# 1   - Consumers on the drugs are pulling back in t...                45
# 6   - Recent studies evaluate risks associated wit...                33
# 27  - The kidney outcomes study on Ozempic was sto...                21
# 0   - Intestinal blockage (ileus) added as a poten...                76
#
#                                       rebuttal_prompt  \
# 41  \n    Task:\n    Your task is to review the be...
# 61  \n    Task:\n    Your task is to review the be...
# 54  \n    Task:\n    Your task is to review the be...
# 21  \n    Task:\n    Your task is to review the be...
# 24  \n    Task:\n    Your task is to review the be...
# 12  \n    Task:\n    Your task is to review the be...
# 69  \n    Task:\n    Your task is to review the be...
# 64  \n    Task:\n    Your task is to review the be...
# 44  \n    Task:\n    Your task is to review the be...
# 43  \n    Task:\n    Your task is to review the be...
# 36  \n    Task:\n    Your task is to review the be...
# 34  \n    Task:\n    Your task is to review the be...
# 26  \n    Task:\n    Your task is to review the be...
# 13  \n    Task:\n    Your task is to review the be...
# 16  \n    Task:\n    Your task is to review the be...
# 18  \n    Task:\n    Your task is to review the be...
# 19  \n    Task:\n    Your task is to review the be...
# 22  \n    Task:\n    Your task is to review the be...
# 15  \n    Task:\n    Your task is to review the be...
# 38  \n    Task:\n    Your task is to review the be...
# 7   \n    Task:\n    Your task is to review the be...
# 11  \n    Task:\n    Your task is to review the be...
# 49  \n    Task:\n    Your task is to review the be...
# 2   \n    Task:\n    Your task is to review the be...
# 46  \n    Task:\n    Your task is to review the be...
# 51  \n    Task:\n    Your task is to review the be...
# 9   \n    Task:\n    Your task is to review the be...
# 40  \n    Task:\n    Your task is to review the be...
# 42  \n    Task:\n    Your task is to review the be...
# 63  \n    Task:\n    Your task is to review the be...
# 39  \n    Task:\n    Your task is to review the be...
# 3   \n    Task:\n    Your task is to review the be...
# 8   \n    Task:\n    Your task is to review the be...
# 10  \n    Task:\n    Your task is to review the be...
# 28  \n    Task:\n    Your task is to review the be...
# 17  \n    Task:\n    Your task is to review the be...
# 47  \n    Task:\n    Your task is to review the be...
# 30  \n    Task:\n    Your task is to review the be...
# 33  \n    Task:\n    Your task is to review the be...
# 20  \n    Task:\n    Your task is to review the be...
# 14  \n    Task:\n    Your task is to review the be...
# 23  \n    Task:\n    Your task is to review the be...
# 29  \n    Task:\n    Your task is to review the be...
# 31  \n    Task:\n    Your task is to review the be...
# 35  \n    Task:\n    Your task is to review the be...
# 32  \n    Task:\n    Your task is to review the be...
# 1   \n    Task:\n    Your task is to review the be...
# 6   \n    Task:\n    Your task is to review the be...
# 27  \n    Task:\n    Your task is to review the be...
# 0   \n    Task:\n    Your task is to review the be...
#
#                                        counter_points disputability_score  \
# 41  The study was funded by Eli Lilly, the manufac...                   9
# 61  - The trial was sponsored by Eli Lilly, the ma...                   9
# 54  While the article presents Jardiance as a new ...                   9
# 21  - The article lacks critical discussion about ...                   9
# 24  - Ozempic and similar weight-loss medications ...                   9
# 12  1. The article doesn't provide any statements ...                   8
# 69  1. The article states that reports of concerni...                   8
# 64  - The survey of 100 doctors may not be represe...                   8
# 44  1. Although the article suggests that weight-l...                   8
# 43  1. Zepbound and other weight loss drugs may no...                   8
# 36  Counterpoints to refute the claims of the arti...                   8
# 34  1. While the article highlights supply shortag...                   8
# 26  Counter points to the article's claims:\n- The...                   8
# 13  Some counterpoints to refute the claims of the...                   8
# 16  1. The article does not provide specific evide...                   8
# 18  1. The study is observational and can only sho...                   8
# 19  1. The impact on Walmart's sales and shopper b...                   8
# 22  1. The potential serious side effects reported...                   8
# 15  1. The plaintiff's allegations of severe side ...                   8
# 38  1. Clinical studies and FDA approval are based...                   8
# 7   1. The article's focus on the potential of Oze...                   8
# 11  1. While Pfizer's weight-loss pill may have sh...                   8
# 49  1. The article does not provide specific evide...                   7
# 2   1. The article does not provide any specific s...                   7
# 46  1. There are potential benefits of weight loss...                   7
# 51  1. The article fails to mention potential long...                   7
# 9   1. Approved weight loss medications, such as W...                   7
# 40  The article may have exaggerated the risks ass...                   7
# 42  - The article is based on a preprint study tha...                   7
# 63  - The claim of unauthorized versions of Mounja...                   7
# 39  - The article's claims about potential harm to...                   7
# 3   1. The article's negative sentiment may be bia...                   7
# 8   1. The use of Ozempic for weight loss is off-l...                   7
# 10  1. The article does not provide statistical co...                   7
# 28  1. The GI societies have stated that there is ...                   7
# 17  1. The study does not establish causation, onl...                   7
# 47  Compounded drugs can be beneficial for patient...                   7
# 30  1. The article does not provide any specific n...                   7
# 33  - The article's comparison of Mounjaro and Oze...                   7
# 20  1. The concerns about decreased insulin use an...                   7
# 14  The article presents the serious risks associa...                   7
# 23  1. GLP-1 drugs from Novo Nordisk and Eli Lilly...                   7
# 29  - The cost of drugs is often offset by their l...                   7
# 31  Counterpoints to refute the claims of the arti...                   7
# 35  1. The discomfort from the experimental weight...                   7
# 32  1. The study only demonstrates a small risk of...                   7
# 1   1. The current US population using the drugs i...                   7
# 6   - Clinical trials have shown substantial weigh...                   6
# 27  The early termination of the kidney outcomes s...                   6
# 0   1. Pharmaceutical company Novo Nordisk states ...                   6
#
#                                      research_queries
# 41  [Long-term safety and efficacy of tirzepatide ...
# 61  [Long-term cardiovascular safety of Mounjaro v...
# 54  [Jardiance safety profile, Comparison of Jardi...
# 21  [Eli Lilly Ozempic safety concerns, Side effec...
# 24  [Long-term side effects of Ozempic and other w...
# 12  [Patient feedback on the compounded versions o...
# 69  [Detailed analysis of the epidemiological stud...
# 64  [Long-term safety data GLP-1 drugs Eli Lilly a...
# 44  [Long-term effects of weight-loss drugs on con...
# 43  [Long-term efficacy and sustainability of weig...
# 36  [Ozempic clinical trial results, Eli Lilly reg...
# 34  [Effectiveness and safety profile of Eli Lilly...
# 26  [Consumer behavior fast food consumption, GLP-...
# 13  [Long-term effectiveness and cost-savings of w...
# 16  [Comparison of side effects between pill and i...
# 18  [Long-term adverse events of semaglutide and l...
# 19  [Impact of diabetes and weight loss drugs on c...
# 22  [Long-term safety and efficacy of tirzepatide ...
# 15  [Clinical studies on the side effects of Mounj...
# 38  [Mounjaro clinical trial data and findings, Of...
# 7   [Eli Lilly Ozempic risks and side effects, Cli...
# 11  [Clinical trial results of Pfizer's weight-los...
# 49  [Factors contributing to the worldwide shortag...
# 2   [Clinical studies on Mounjaro and its potentia...
# 46  [Long-term effects of GLP-1 medications on mus...
# 51  [Long-term side effects of Zepbound, Comparati...
# 9   [Long-term safety and efficacy of off-label us...
# 40  [Long-term clinical trials of Semaglutide and ...
# 42  [Long-term comparative studies on the cardiova...
# 63  [Independent testing of alleged counterfeit Mo...
# 39  [Long-term impact of weight-loss medicines on ...
# 3   [Long-term clinical outcomes of GLP-1 drugs li...
# 8   [FDA regulations on off-label usage of medicat...
# 10  [Incidence of severe stomach issues in non-med...
# 28  [Long-term clinical studies on the safety and ...
# 17  [Long-term clinical trials assessing the causa...
# 47  [FDA regulations on compounding pharmacies and...
# 30  [Eli Lilly Ozempic market share, Comparison of...
# 33  [Long-term safety and real-world effectiveness...
# 20  [Impact of GLP-1 drugs on insulin use and bloo...
# 14  [FDA inspection report details for Ozempic and...
# 23  [Long-term safety studies of GLP-1 drugs from ...
# 29  [Long-term benefits of Ozempic and Wegovy, Com...
# 31  [Eli Lilly Ozempic safety and efficacy studies...
# 35  [Weight-loss pill market analysis, Comparison ...
# 32  [Long-term safety data of GLP-1 products from ...
# 1   [Long-term impact of weight loss drugs on cons...
# 6   [Long-term studies on the safety and efficacy ...
# 27  [Eli Lilly Ozempic FLOW study interim analysis...
# 0   [Clinical studies on the severity and duration...
#
# [50 rows x 22 columns]

# %%
write_deltalake(
    table_path_out,
    df.reset_index(),
    partition_by=['query', 'published date str'],
    mode='overwrite',
    # overwrite_schema=True,
    partition_filters=[
        ('query', '=', query),
        ('published date str', '>=', start_date_str), 
        ('published date str', '<=', current_date_str),
    ]
)

# %%
DeltaTable(table_path_out).to_pandas()
# Out:
#     index                                              title  \
# 0      44  Weight-loss drugs are impacting everything fro...
# 1      43  How does the weight loss drug Zepbound compare...
# 2      36  Behold the Ozempic effect on business - Financ...
# 3      22  Eli Lilly says weight loss drug Zepbound is no...
# 4      41  Diabetes drug Mounjaro helped dieters shed 60 ...
# 5      16  Ozempic Pills for Weight Loss Don't Reduce Pri...
# 6      15  Eli Lilly Seeks Diabetes Drug Lawsuit Dismissa...
# 7      21  Ozempic and other weight-loss drugs will power...
# 8      61  Mounjaro vs. Insulin: Which Is More Effective ...
# 9      54  US FDA approves Jardiance® for the treatment o...
# 10     18  New study ties weight-loss drugs Wegovy, Ozemp...
# 11     19  Wall Street Breakfast Podcast: Walmart Links O...
# 12     17  Ozempic, Wegovy linked to severe medical condi...
# 13     20  These diabetes stocks, pummeled by the Ozempic...
# 14     11  Pfizer struggles to catch up to Ozempic, Wegov...
# 15     38  Mounjaro Lawsuit: Eli Lilly Low-Grade Mounjaro...
# 16     51  Zepbound is Eli Lilly’s new weight loss drug: ...
# 17     13  The rationing of popular weight-loss drugs Oze...
# 18     34  Makers of Ozempic, Mounjaro race to ramp up su...
# 19     33  2 Reasons Why Eli Lilly's Mounjaro Might Beat ...
# 20     32  Study shows Novo's Ozempic, Wegovy pose risk o...
# 21     49  Ozempic shortage expected to last into 2024: H...
# 22      7  Can Ozempic, Wegovy Treat Alcoholism? - Bloomberg
# 23     42  For Weight Loss and Blood Sugar, Mounjaro May ...
# 24     40  Popular Weight-Loss Drugs Come with Side Effec...
# 25     39  Could Ozempic Harm These 3 Medical Device Stoc...
# 26     29  Ozempic and Wegovy Don't Cost What You Think T...
# 27     46  Weight-loss drugs like Ozempic and Wegovy may ...
# 28     47  Eli Lilly Files Lawsuits Against Clinics Selli...
# 29      2  Mounjaro Lawsuits - Lawsuit Information Center...
# 30      1  Ozempic, Wegovy, and other weight loss drugs' ...
# 31      8  Woman dies after taking Ozempic to slim down f...
# 32     30  Roche Chases Novo's Ozempic, Wegovy With $3 Bi...
# 33     28  Beyond obesity care: Flood of popular weight l...
# 34      9  Diabetes Weight Loss Drugs Lawsuits - The Lega...
# 35     10  Diabetes Drugs Used for Weight Loss Could Caus...
# 36     31  Tiktok's Fueling Demand for Weight Loss Drugs ...
# 37     35  Pfizer Struggles To Catch Up To Ozempic, Wegov...
# 38      3  What's the Ozempic effect on the stock market?...
# 39     23  FDA adds warning for intestinal blockage on No...
# 40     69  1 Big Risk Facing Ozempic, Wegovy, and Other G...
# 41     14  Microbial Contaminant Control Problems at Ozem...
# 42      6  Anti-obesity drugs' side effects: what we know...
# 43     27  Lilly (LLY) Up on NVO's Ozempic Early Success ...
# 44     64  Doctors raise cost, coverage concerns over new...
# 45     63  Eli Lilly sues clinics allegedly selling knock...
# 46      0  Intestinal Blockage Added as Potential Ozempic...
# 47     26  Is Ozempic a danger to the McDonald's share pr...
# 48     12  Florida pharmacies selling GLP-1 knockoffs fac...
# 49     24               Should We End Obesity? | TIME - TIME
#
#                                           description published date  \
# 0   Weight-loss drugs are impacting everything fro...     2023-11-13
# 1   How does the weight loss drug Zepbound compare...     2023-11-13
# 2   Behold the Ozempic effect on business  Financi...     2023-11-19
# 3   Eli Lilly says weight loss drug Zepbound is no...     2023-12-06
# 4   Diabetes drug Mounjaro helped dieters shed 60 ...     2023-10-15
# 5   Ozempic Pills for Weight Loss Don't Reduce Pri...     2023-11-17
# 6   Eli Lilly Seeks Diabetes Drug Lawsuit Dismissa...     2023-11-17
# 7   Ozempic and other weight-loss drugs will power...     2023-11-04
# 8   Mounjaro vs. Insulin: Which Is More Effective ...     2023-10-03
# 9   US FDA approves Jardiance® for the treatment o...     2023-09-22
# 10  New study ties weight-loss drugs Wegovy, Ozemp...     2023-10-05
# 11  Wall Street Breakfast Podcast: Walmart Links O...     2023-10-05
# 12  Ozempic, Wegovy linked to severe medical condi...     2023-10-05
# 13  These diabetes stocks, pummeled by the Ozempic...     2023-10-05
# 14  Pfizer struggles to catch up to Ozempic, Wegov...     2023-12-02
# 15  Mounjaro Lawsuit: Eli Lilly Low-Grade Mounjaro...     2023-10-10
# 16  Zepbound is Eli Lilly’s new weight loss drug: ...     2023-11-09
# 17  The rationing of popular weight-loss drugs Oze...     2023-11-15
# 18  Makers of Ozempic, Mounjaro race to ramp up su...     2023-10-06
# 19  2 Reasons Why Eli Lilly's Mounjaro Might Beat ...     2023-10-06
# 20  Study shows Novo's Ozempic, Wegovy pose risk o...     2023-10-06
# 21  Ozempic shortage expected to last into 2024: H...     2023-12-07
# 22   Can Ozempic, Wegovy Treat Alcoholism?  Bloomberg     2023-12-08
# 23  For Weight Loss and Blood Sugar, Mounjaro May ...     2023-09-26
# 24  Popular Weight-Loss Drugs Come with Side Effec...     2023-10-19
# 25  Could Ozempic Harm These 3 Medical Device Stoc...     2023-11-25
# 26  Ozempic and Wegovy Don't Cost What You Think T...     2023-10-22
# 27  Weight-loss drugs like Ozempic and Wegovy may ...     2023-09-27
# 28  Eli Lilly Files Lawsuits Against Clinics Selli...     2023-09-27
# 29  Mounjaro Lawsuits  Lawsuit Information Center ...     2023-10-31
# 30  Ozempic, Wegovy, and other weight loss drugs' ...     2023-10-31
# 31  Woman dies after taking Ozempic to slim down f...     2023-11-06
# 32  Roche Chases Novo's Ozempic, Wegovy With $3 Bi...     2023-12-04
# 33  Beyond obesity care: Flood of popular weight l...     2023-09-16
# 34  Diabetes Weight Loss Drugs Lawsuits  The Legal...     2023-10-27
# 35  Diabetes Drugs Used for Weight Loss Could Caus...     2023-10-27
# 36  Tiktok's Fueling Demand for Weight Loss Drugs ...     2023-11-27
# 37  Pfizer Struggles To Catch Up To Ozempic, Wegov...     2023-12-01
# 38  What's the Ozempic effect on the stock market?...     2023-11-11
# 39  FDA adds warning for intestinal blockage on No...     2023-09-28
# 40  1 Big Risk Facing Ozempic, Wegovy, and Other G...     2023-10-14
# 41  Microbial Contaminant Control Problems at Ozem...     2023-09-20
# 42  Anti-obesity drugs' side effects: what we know...     2023-10-13
# 43  Lilly (LLY) Up on NVO's Ozempic Early Success ...     2023-10-12
# 44  Doctors raise cost, coverage concerns over new...     2023-09-19
# 45  Eli Lilly sues clinics allegedly selling knock...     2023-09-19
# 46  Intestinal Blockage Added as Potential Ozempic...     2023-10-04
# 47  Is Ozempic a danger to the McDonald's share pr...     2023-10-29
# 48  Florida pharmacies selling GLP-1 knockoffs fac...     2023-11-30
# 49                Should We End Obesity? | TIME  TIME     2023-11-08
#
#                                                   url  \
# 0   https://news.google.com/rss/articles/CBMiZ2h0d...
# 1   https://news.google.com/rss/articles/CBMiXWh0d...
# 2   https://news.google.com/rss/articles/CBMiP2h0d...
# 3   https://news.google.com/rss/articles/CBMiZ2h0d...
# 4   https://news.google.com/rss/articles/CBMihQFod...
# 5   https://news.google.com/rss/articles/CBMicGh0d...
# 6   https://news.google.com/rss/articles/CBMiU2h0d...
# 7   https://news.google.com/rss/articles/CBMiTWh0d...
# 8   https://news.google.com/rss/articles/CBMid2h0d...
# 9   https://news.google.com/rss/articles/CBMieGh0d...
# 10  https://news.google.com/rss/articles/CBMiPWh0d...
# 11  https://news.google.com/rss/articles/CBMiZWh0d...
# 12  https://news.google.com/rss/articles/CBMifGh0d...
# 13  https://news.google.com/rss/articles/CBMikAFod...
# 14  https://news.google.com/rss/articles/CBMidmh0d...
# 15  https://news.google.com/rss/articles/CBMiMWh0d...
# 16  https://news.google.com/rss/articles/CBMiZmh0d...
# 17  https://news.google.com/rss/articles/CBMiQ2h0d...
# 18  https://news.google.com/rss/articles/CBMiSGh0d...
# 19  https://news.google.com/rss/articles/CBMiW2h0d...
# 20  https://news.google.com/rss/articles/CBMifWh0d...
# 21  https://news.google.com/rss/articles/CBMimwFod...
# 22  https://news.google.com/rss/articles/CBMiWWh0d...
# 23  https://news.google.com/rss/articles/CBMib2h0d...
# 24  https://news.google.com/rss/articles/CBMiXGh0d...
# 25  https://news.google.com/rss/articles/CBMiW2h0d...
# 26  https://news.google.com/rss/articles/CBMiSGh0d...
# 27  https://news.google.com/rss/articles/CBMiXmh0d...
# 28  https://news.google.com/rss/articles/CBMieGh0d...
# 29  https://news.google.com/rss/articles/CBMiQGh0d...
# 30  https://news.google.com/rss/articles/CBMibWh0d...
# 31  https://news.google.com/rss/articles/CBMiYWh0d...
# 32  https://news.google.com/rss/articles/CBMibGh0d...
# 33  https://news.google.com/rss/articles/CBMijAFod...
# 34  https://news.google.com/rss/articles/CBMiaGh0d...
# 35  https://news.google.com/rss/articles/CBMipQFod...
# 36  https://news.google.com/rss/articles/CBMif2h0d...
# 37  https://news.google.com/rss/articles/CBMiemh0d...
# 38  https://news.google.com/rss/articles/CBMieWh0d...
# 39  https://news.google.com/rss/articles/CBMiaWh0d...
# 40  https://news.google.com/rss/articles/CBMiW2h0d...
# 41  https://news.google.com/rss/articles/CBMiXGh0d...
# 42  https://news.google.com/rss/articles/CBMiMmh0d...
# 43  https://news.google.com/rss/articles/CBMiSmh0d...
# 44  https://news.google.com/rss/articles/CBMie2h0d...
# 45  https://news.google.com/rss/articles/CBMia2h0d...
# 46  https://news.google.com/rss/articles/CBMiUmh0d...
# 47  https://news.google.com/rss/articles/CBMiVGh0d...
# 48  https://news.google.com/rss/articles/CBMif2h0d...
# 49  https://news.google.com/rss/articles/CBMiOWh0d...
#
#                                             publisher  \
# 0   {'href': 'https://fortune.com', 'title': 'Fort...
# 1   {'href': 'https://www.uchealth.org', 'title': ...
# 2   {'href': 'https://www.ft.com', 'title': 'Finan...
# 3   {'href': 'https://www.wxyz.com', 'title': 'WXY...
# 4   {'href': 'https://www.nbcchicago.com', 'title'...
# 5   {'href': 'https://www.bloomberg.com', 'title':...
# 6   {'href': 'https://medtruth.com', 'title': 'Med...
# 7   {'href': 'https://finance.yahoo.com', 'title':...
# 8   {'href': 'https://www.healthline.com', 'title'...
# 9   {'href': 'https://investor.lilly.com', 'title'...
# 10  {'href': 'https://www.cbc.ca', 'title': 'CBC N...
# 11  {'href': 'https://seekingalpha.com', 'title': ...
# 12  {'href': 'https://www.nbcnews.com', 'title': '...
# 13  {'href': 'https://www.morningstar.com', 'title...
# 14  {'href': 'https://www.latimes.com', 'title': '...
# 15  {'href': 'https://www.drugwatch.com', 'title':...
# 16  {'href': 'https://www.nbcnews.com', 'title': '...
# 17  {'href': 'https://www.politico.com', 'title': ...
# 18    {'href': 'https://www.cnn.com', 'title': 'CNN'}
# 19  {'href': 'https://www.fool.com', 'title': 'The...
# 20  {'href': 'https://www.fiercepharma.com', 'titl...
# 21  {'href': 'https://www.cp24.com', 'title': 'CP24'}
# 22  {'href': 'https://www.bloomberg.com', 'title':...
# 23  {'href': 'https://www.healthline.com', 'title'...
# 24  {'href': 'https://www.scientificamerican.com',...
# 25  {'href': 'https://www.fool.com', 'title': 'The...
# 26  {'href': 'https://www.nytimes.com', 'title': '...
# 27  {'href': 'https://fortune.com', 'title': 'Fort...
# 28  {'href': 'https://www.healthline.com', 'title'...
# 29  {'href': 'https://www.lawsuit-information-cent...
# 30  {'href': 'https://finance.yahoo.com', 'title':...
# 31  {'href': 'https://nypost.com', 'title': 'New Y...
# 32  {'href': 'https://www.bloomberg.com', 'title':...
# 33  {'href': 'https://www.healio.com', 'title': 'H...
# 34  {'href': 'https://www.legalexaminer.com', 'tit...
# 35  {'href': 'https://www.legalexaminer.com', 'tit...
# 36  {'href': 'https://www.bloomberg.com', 'title':...
# 37  {'href': 'https://www.bloomberg.com', 'title':...
# 38  {'href': 'https://www.theglobeandmail.com', 't...
# 39  {'href': 'https://www.fiercepharma.com', 'titl...
# 40  {'href': 'https://www.fool.com', 'title': 'The...
# 41  {'href': 'https://www.aboutlawsuits.com', 'tit...
# 42  {'href': 'https://www.nature.com', 'title': 'N...
# 43  {'href': 'https://finance.yahoo.com', 'title':...
# 44  {'href': 'https://www.fiercepharma.com', 'titl...
# 45  {'href': 'https://www.cnbc.com', 'title': 'CNBC'}
# 46  {'href': 'https://www.drugwatch.com', 'title':...
# 47  {'href': 'https://uk.finance.yahoo.com', 'titl...
# 48  {'href': 'https://www.fiercepharma.com', 'titl...
# 49      {'href': 'https://time.com', 'title': 'TIME'}
#
#                       query             query end date  published datetime  \
# 0   Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-13 08:00:00
# 1   Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-13 08:00:00
# 2   Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-19 08:00:00
# 3   Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-12-06 20:42:50
# 4   Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-15 07:00:00
# 5   Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-17 08:00:00
# 6   Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-17 08:00:00
# 7   Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-04 07:00:00
# 8   Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-03 07:00:00
# 9   Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-09-22 07:00:00
# 10  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-05 07:00:00
# 11  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-05 07:00:00
# 12  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-05 07:00:00
# 13  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-05 07:00:00
# 14  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-12-02 08:00:00
# 15  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-10 06:49:14
# 16  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-09 08:00:00
# 17  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-15 08:00:00
# 18  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-06 07:00:00
# 19  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-06 07:00:00
# 20  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-06 07:00:00
# 21  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-12-07 00:39:37
# 22  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-12-08 11:00:11
# 23  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-09-26 07:00:00
# 24  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-19 07:00:00
# 25  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-25 08:00:00
# 26  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-22 07:00:00
# 27  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-09-27 07:00:00
# 28  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-09-27 07:00:00
# 29  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-31 07:00:00
# 30  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-31 07:00:00
# 31  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-06 08:00:00
# 32  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-12-04 12:45:29
# 33  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-09-16 07:00:00
# 34  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-27 07:00:00
# 35  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-27 07:00:00
# 36  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-27 08:00:00
# 37  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-12-01 08:00:00
# 38  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-11 08:00:00
# 39  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-09-28 07:00:00
# 40  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-14 07:00:00
# 41  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-09-20 07:00:00
# 42  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-13 07:00:00
# 43  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-12 07:00:00
# 44  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-09-19 07:00:00
# 45  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-09-19 07:00:00
# 46  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-04 07:00:00
# 47  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-10-29 07:00:00
# 48  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-30 08:00:00
# 49  Eli Lilly Ozempic Risks 2023-12-13 02:07:22.818228 2023-11-08 08:00:00
#
#    published date str  ...                                   article keywords  \
# 0          2023-11-13  ...  [drugs, impacting, surgery, weight, impact, sn...
# 1          2023-11-13  ...  [drug, drugs, weight, ozempic, zepbound, work,...
# 2          2023-11-19  ...  [reasons, reliable, ozempic, secure, ft, socia...
# 3          2023-12-06  ...  [drug, weight, eli, doses, zepbound, youre, pa...
# 4          2023-10-15  ...  [drug, shed, weight, finds, dieters, helped, t...
# 5          2023-11-17  ...  [drugs, effects, sold, issues, versions, table...
# 6          2023-11-17  ...  [drug, warning, eli, claims, diabetes, label, ...
# 7          2023-11-04  ...  [gains, drugs, power, weight, ozempic, billion...
# 8          2023-10-03  ...  [trial, group, fastacting, weight, insulin, vs...
# 9          2023-09-22  ...  [disease, adults, risk, fda, approves, blood, ...
# 10         2023-10-05  ...  [drugs, ties, serious, conditions, risk, drug,...
# 11         2023-10-05  ...  [drugs, street, podcast, weight, 03, company, ...
# 12         2023-10-05  ...  [drugs, drug, risk, weight, finds, medications...
# 13         2023-10-05  ...  [bargains, device, look, pummeled, insulin, oz...
# 14         2023-12-02  ...  [struggles, drugs, weight, catch, rival, pills...
# 15         2023-10-10  ...  [updates, lawsuits, lowgrade, eli, attorney, g...
# 16         2023-11-09  ...  [drug, lillys, effects, know, weight, eli, zep...
# 17         2023-11-15  ...  [rationing, drugs, health, weight, state, stat...
# 18         2023-10-06  ...  [drugs, medicines, weight, ozempic, supply, ra...
# 19         2023-10-06  ...  [drug, lillys, weight, eli, reasons, ozempic, ...
# 20         2023-10-06  ...  [drugs, risk, pose, small, semaglutide, study,...
# 21         2023-12-07  ...  [drugs, health, yearit, canada, 2024, expectin...
# 22         2023-12-08  ...  [drinking, china, trading, open, latest, stop,...
# 23         2023-09-26  ...  [drugs, drug, weight, blood, semaglutide, dose...
# 24         2023-10-19  ...  [drugs, effects, weight, semaglutide, medicati...
# 25         2023-11-25  ...  [medicines, segment, device, surgery, cardiova...
# 26         2023-10-22  ...  [drugs, health, generally, companies, willett,...
# 27         2023-09-27  ...  [weight, muscle, loss, say, older, adults, fat...
# 28         2023-09-27  ...  [drug, drugs, versions, lawsuits, fda, eli, se...
# 29         2023-10-31  ...  [drug, weight, lawsuits, ozempic, cases, gallb...
# 30         2023-10-31  ...  [drugs, told, health, weight, impact, business...
# 31         2023-11-06  ...  [60, drug, dies, shouldnt, taking, gone, woman...
# 32         2023-12-04  ...  [drugs, cant, investors, china, trading, open,...
# 33         2023-09-16  ...  [weight, semaglutide, novo, loss, flood, opens...
# 34         2023-10-27  ...  [drugs, effects, lawsuits, weight, medications...
# 35         2023-10-27  ...  [drugs, effects, type, issues, weight, cause, ...
# 36         2023-11-27  ...  [drugs, lillys, drug, hit, ozempic, zepbound, ...
# 37         2023-12-01  ...  [drugs, weight, gold, rival, ozempic, zepbound...
# 38         2023-11-11  ...  [drugs, drug, stock, investors, companies, oze...
# 39         2023-09-28  ...  [risk, flagging, ileus, update, fda, intestina...
# 40         2023-10-14  ...  [drugs, risk, effects, weight, company, ozempi...
# 41         2023-09-20  ...  [weight, control, novo, users, loss, stomach, ...
# 42         2023-10-13  ...  [drugs, effects, m, far, know, j, med, semaglu...
# 43         2023-10-12  ...  [stock, lly, company, early, ii, ozempic, succ...
# 44         2023-09-19  ...  [suffer, issues, weight, semaglutide, poor, no...
# 45         2023-09-19  ...  [drug, drugs, versions, eli, selling, ozempic,...
# 46         2023-10-04  ...  [blockage, effects, drug, fda, intestinal, weg...
# 47         2023-10-29  ...  [ozempic, motley, fool, danger, mcdonalds, thr...
# 48         2023-11-30  ...  [drugs, versions, lawsuits, companies, knockof...
# 49         2023-11-08  ...  [disease, health, weight, ozempic, end, patien...
#
#                                      sentiment_prompt sentiment_score  \
# 0   \n    - Your task is to read the article below...               8
# 1   \n    - Your task is to read the article below...               8
# 2   \n    - Your task is to read the article below...               8
# 3   \n    - Your task is to read the article below...               9
# 4   \n    - Your task is to read the article below...               7
# 5   \n    - Your task is to read the article below...               9
# 6   \n    - Your task is to read the article below...               9
# 7   \n    - Your task is to read the article below...               8
# 8   \n    - Your task is to read the article below...               8
# 9   \n    - Your task is to read the article below...               8
# 10  \n    - Your task is to read the article below...               9
# 11  \n    - Your task is to read the article below...               8
# 12  \n    - Your task is to read the article below...               9
# 13  \n    - Your task is to read the article below...               8
# 14  \n    - Your task is to read the article below...               9
# 15  \n    - Your task is to read the article below...               9
# 16  \n    - Your task is to read the article below...               8
# 17  \n    - Your task is to read the article below...               9
# 18  \n    - Your task is to read the article below...               8
# 19  \n    - Your task is to read the article below...               8
# 20  \n    - Your task is to read the article below...               9
# 21  \n    - Your task is to read the article below...               8
# 22  \n    - Your task is to read the article below...               9
# 23  \n    - Your task is to read the article below...               8
# 24  \n    - Your task is to read the article below...               8
# 25  \n    - Your task is to read the article below...               8
# 26  \n    - Your task is to read the article below...               8
# 27  \n    - Your task is to read the article below...               8
# 28  \n    - Your task is to read the article below...               8
# 29  \n    - Your task is to read the article below...               9
# 30  \n    - Your task is to read the article below...               9
# 31  \n    - Your task is to read the article below...               9
# 32  \n    - Your task is to read the article below...               8
# 33  \n    - Your task is to read the article below...               9
# 34  \n    - Your task is to read the article below...               9
# 35  \n    - Your task is to read the article below...               9
# 36  \n    - Your task is to read the article below...               8
# 37  \n    - Your task is to read the article below...               8
# 38  \n    - Your task is to read the article below...               9
# 39  \n    - Your task is to read the article below...               8
# 40  \n    - Your task is to read the article below...               7
# 41  \n    - Your task is to read the article below...               9
# 42  \n    - Your task is to read the article below...               9
# 43  \n    - Your task is to read the article below...               8
# 44  \n    - Your task is to read the article below...               7
# 45  \n    - Your task is to read the article below...               8
# 46  \n    - Your task is to read the article below...               9
# 47  \n    - Your task is to read the article below...               8
# 48  \n    - Your task is to read the article below...               9
# 49  \n    - Your task is to read the article below...               8
#
#                                 sentiment_explanation  \
# 0   The sentiment score is 8 because the article d...
# 1   The sentiment score is given as 8 due to the n...
# 2   The sentiment score is given as 8 due to the a...
# 3   The sentiment score is 9 due to the numerous p...
# 4   The sentiment score of 7 is given because the ...
# 5   The sentiment score is 9 due to the negative t...
# 6   The sentiment score is given a 9 due to the st...
# 7   The sentiment score is given as 8 due to the f...
# 8   The sentiment negativity score is 8 because th...
# 9   The sentiment score is given an 8 out of 10 du...
# 10  The sentiment negativity score is given as 9 d...
# 11  The sentiment score is relatively high due to ...
# 12  The sentiment score is given a 9 due to the si...
# 13  The sentiment negativity score is 8 because th...
# 14  The article overall portrays a very negative s...
# 15  The sentiment score is 9 because the article p...
# 16  The sentiment score is 8 because the article h...
# 17  The article expresses strong negative sentimen...
# 18  The sentiment score is high because the articl...
# 19  The sentiment negativity score is 8 because th...
# 20  The sentiment score is 9 because the article h...
# 21  The sentiment negativity score is 8, indicatin...
# 22  The sentiment negativity score is 9 because th...
# 23  The sentiment score is given an 8 due to the n...
# 24  The sentiment score is 8 because the article h...
# 25  The sentiment negativity score is 8 because th...
# 26  The sentiment score is 8 because the article h...
# 27  The sentiment negativity score is 8 due to the...
# 28  The sentiment negativity score is 8 because th...
# 29  The sentiment score is 9 because the article d...
# 30  The article portrays a highly negative sentime...
# 31  The sentiment score is given a high rating due...
# 32  The sentiment score is 8 because the article d...
# 33  The sentiment score is high due to numerous ne...
# 34  The sentiment score of 9 is given due to the n...
# 35  The sentiment towards Eli Lilly Ozempic and si...
# 36  The sentiment negativity score is high because...
# 37  The sentiment negativity score of 8 is given b...
# 38  The sentiment negativity score is 9 due to the...
# 39  The sentiment negativity score is 8 due to the...
# 40  The sentiment negativity score is 7 because th...
# 41  The sentiment score is given a 9 due to the nu...
# 42  The sentiment score is given a 9 because the a...
# 43  The sentiment score is 8 out of 10 as the arti...
# 44  The sentiment negativity score is 7 because th...
# 45  The sentiment score is given as 8 due to the n...
# 46  The sentiment score is high due to the numerou...
# 47  The sentiment negativity score is high due to ...
# 48  The sentiment score is given a 9 because the a...
# 49  The sentiment negativity score of 8 is given d...
#
#                                       negative_claims __index_level_0__  \
# 0   - Retailers and food/beverage companies are co...                12
# 1   - Zepbound and other weight loss drugs have hi...                11
# 2   - The article highlights potential health risk...                 9
# 3   - Zepbound may cause tumors in the thyroid, in...                43
# 4   - Side effects including nausea, diarrhea, and...                20
# 5   - Obesity pills under development have major s...                68
# 6    - Eli Lilly seeking dismissal of lawsuit file...                67
# 7   - The article lacks critical discussion about ...                51
# 8    - Mounjaro showed significantly fewer instanc...                73
# 9   - Jardiance is not recommended for use to impr...                32
# 10  - Medications in the same class as Wegovy and ...                26
# 11  Walmart reports a slight pullback in overall b...                28
# 12  - Research published in the Journal of the Ame...                25
# 13  - Diabetes device stocks have been crushed by ...                27
# 14  - Pfizer's experimental weight-loss pill cause...                58
# 15  - Mounjaro and Ozempic are alleged to cause se...                60
# 16  - The high cost of Zepbound may be a barrier f...                17
# 17  - State health plans imposing clinical lifesty...                57
# 18  - The demand for Eli Lilly's medicines, especi...                 4
# 19  - Mounjaro appears to be more effective at con...                 5
# 20  - Novo's popular GLP-1 products are linked to ...                 3
# 21  - Worldwide shortage of diabetes drugs, includ...                64
# 22  The article does not mention specific negative...                65
# 23  - Mounjaro (Tirzepatide) was found to be super...                23
# 24   - Increased incidence of pancreatitis and gas...                61
# 25  - The article suggests that the popularity of ...                36
# 26       - Expensive cost of Ozempic and Wegovy drugs                56
# 27  - Weight-loss drugs like Ozempic and Wegovy ma...                 7
# 28  - Compounded medications do not have the same ...                 6
# 29  - Using higher doses of Mounjaro for weight lo...                46
# 30  - Consumers on the drugs are pulling back in t...                45
# 31  - An Australian woman died from gastrointestin...                62
# 32  The article does not contain specific negative...                55
# 33  - Lawsuit alleging Novo Nordisk and Eli Lilly ...                75
# 34  - Massive shortages of diabetes medications fo...                70
# 35  - Ozempic and similar diabetes drugs used for ...                71
# 36  - Ads, pop culture, and social media have cont...                48
# 37  - Pfizer dropping development of an experiment...                44
# 38  - Excessive speculation and irrational exubera...                 1
# 39  - The FDA has updated the label for Novo’s Oze...                14
# 40  - Ozempic and other GLP-1 receptor agonists ma...                35
# 41  - Increasing evidence of serious risk of stoma...                63
# 42  - Recent studies evaluate risks associated wit...                33
# 43  - The kidney outcomes study on Ozempic was sto...                21
# 44  - Doctors have significant concerns about the ...                30
# 45  - Eli Lilly suing medical spas, wellness clini...                29
# 46  - Intestinal blockage (ileus) added as a poten...                76
# 47  - GLP-1 weight-loss drugs like Ozempic and Weg...                50
# 48  - Novo Nordisk alleges that Brooksville Pharma...                52
# 49  - The widespread use and marketing of Ozempic ...                16
#
#                                       rebuttal_prompt  \
# 0   \n    Task:\n    Your task is to review the be...
# 1   \n    Task:\n    Your task is to review the be...
# 2   \n    Task:\n    Your task is to review the be...
# 3   \n    Task:\n    Your task is to review the be...
# 4   \n    Task:\n    Your task is to review the be...
# 5   \n    Task:\n    Your task is to review the be...
# 6   \n    Task:\n    Your task is to review the be...
# 7   \n    Task:\n    Your task is to review the be...
# 8   \n    Task:\n    Your task is to review the be...
# 9   \n    Task:\n    Your task is to review the be...
# 10  \n    Task:\n    Your task is to review the be...
# 11  \n    Task:\n    Your task is to review the be...
# 12  \n    Task:\n    Your task is to review the be...
# 13  \n    Task:\n    Your task is to review the be...
# 14  \n    Task:\n    Your task is to review the be...
# 15  \n    Task:\n    Your task is to review the be...
# 16  \n    Task:\n    Your task is to review the be...
# 17  \n    Task:\n    Your task is to review the be...
# 18  \n    Task:\n    Your task is to review the be...
# 19  \n    Task:\n    Your task is to review the be...
# 20  \n    Task:\n    Your task is to review the be...
# 21  \n    Task:\n    Your task is to review the be...
# 22  \n    Task:\n    Your task is to review the be...
# 23  \n    Task:\n    Your task is to review the be...
# 24  \n    Task:\n    Your task is to review the be...
# 25  \n    Task:\n    Your task is to review the be...
# 26  \n    Task:\n    Your task is to review the be...
# 27  \n    Task:\n    Your task is to review the be...
# 28  \n    Task:\n    Your task is to review the be...
# 29  \n    Task:\n    Your task is to review the be...
# 30  \n    Task:\n    Your task is to review the be...
# 31  \n    Task:\n    Your task is to review the be...
# 32  \n    Task:\n    Your task is to review the be...
# 33  \n    Task:\n    Your task is to review the be...
# 34  \n    Task:\n    Your task is to review the be...
# 35  \n    Task:\n    Your task is to review the be...
# 36  \n    Task:\n    Your task is to review the be...
# 37  \n    Task:\n    Your task is to review the be...
# 38  \n    Task:\n    Your task is to review the be...
# 39  \n    Task:\n    Your task is to review the be...
# 40  \n    Task:\n    Your task is to review the be...
# 41  \n    Task:\n    Your task is to review the be...
# 42  \n    Task:\n    Your task is to review the be...
# 43  \n    Task:\n    Your task is to review the be...
# 44  \n    Task:\n    Your task is to review the be...
# 45  \n    Task:\n    Your task is to review the be...
# 46  \n    Task:\n    Your task is to review the be...
# 47  \n    Task:\n    Your task is to review the be...
# 48  \n    Task:\n    Your task is to review the be...
# 49  \n    Task:\n    Your task is to review the be...
#
#                                        counter_points  disputability_score  \
# 0   1. Although the article suggests that weight-l...                    8
# 1   1. Zepbound and other weight loss drugs may no...                    8
# 2   Counterpoints to refute the claims of the arti...                    8
# 3   1. The potential serious side effects reported...                    8
# 4   The study was funded by Eli Lilly, the manufac...                    9
# 5   1. The article does not provide specific evide...                    8
# 6   1. The plaintiff's allegations of severe side ...                    8
# 7   - The article lacks critical discussion about ...                    9
# 8   - The trial was sponsored by Eli Lilly, the ma...                    9
# 9   While the article presents Jardiance as a new ...                    9
# 10  1. The study is observational and can only sho...                    8
# 11  1. The impact on Walmart's sales and shopper b...                    8
# 12  1. The study does not establish causation, onl...                    7
# 13  1. The concerns about decreased insulin use an...                    7
# 14  1. While Pfizer's weight-loss pill may have sh...                    8
# 15  1. Clinical studies and FDA approval are based...                    8
# 16  1. The article fails to mention potential long...                    7
# 17  Some counterpoints to refute the claims of the...                    8
# 18  1. While the article highlights supply shortag...                    8
# 19  - The article's comparison of Mounjaro and Oze...                    7
# 20  1. The study only demonstrates a small risk of...                    7
# 21  1. The article does not provide specific evide...                    7
# 22  1. The article's focus on the potential of Oze...                    8
# 23  - The article is based on a preprint study tha...                    7
# 24  The article may have exaggerated the risks ass...                    7
# 25  - The article's claims about potential harm to...                    7
# 26  - The cost of drugs is often offset by their l...                    7
# 27  1. There are potential benefits of weight loss...                    7
# 28  Compounded drugs can be beneficial for patient...                    7
# 29  1. The article does not provide any specific s...                    7
# 30  1. The current US population using the drugs i...                    7
# 31  1. The use of Ozempic for weight loss is off-l...                    7
# 32  1. The article does not provide any specific n...                    7
# 33  1. The GI societies have stated that there is ...                    7
# 34  1. Approved weight loss medications, such as W...                    7
# 35  1. The article does not provide statistical co...                    7
# 36  Counterpoints to refute the claims of the arti...                    7
# 37  1. The discomfort from the experimental weight...                    7
# 38  1. The article's negative sentiment may be bia...                    7
# 39  1. GLP-1 drugs from Novo Nordisk and Eli Lilly...                    7
# 40  1. The article states that reports of concerni...                    8
# 41  The article presents the serious risks associa...                    7
# 42  - Clinical trials have shown substantial weigh...                    6
# 43  The early termination of the kidney outcomes s...                    6
# 44  - The survey of 100 doctors may not be represe...                    8
# 45  - The claim of unauthorized versions of Mounja...                    7
# 46  1. Pharmaceutical company Novo Nordisk states ...                    6
# 47  Counter points to the article's claims:\n- The...                    8
# 48  1. The article doesn't provide any statements ...                    8
# 49  - Ozempic and similar weight-loss medications ...                    9
#
#                                      research_queries
# 0   [Long-term effects of weight-loss drugs on con...
# 1   [Long-term efficacy and sustainability of weig...
# 2   [Ozempic clinical trial results, Eli Lilly reg...
# 3   [Long-term safety and efficacy of tirzepatide ...
# 4   [Long-term safety and efficacy of tirzepatide ...
# 5   [Comparison of side effects between pill and i...
# 6   [Clinical studies on the side effects of Mounj...
# 7   [Eli Lilly Ozempic safety concerns, Side effec...
# 8   [Long-term cardiovascular safety of Mounjaro v...
# 9   [Jardiance safety profile, Comparison of Jardi...
# 10  [Long-term adverse events of semaglutide and l...
# 11  [Impact of diabetes and weight loss drugs on c...
# 12  [Long-term clinical trials assessing the causa...
# 13  [Impact of GLP-1 drugs on insulin use and bloo...
# 14  [Clinical trial results of Pfizer's weight-los...
# 15  [Mounjaro clinical trial data and findings, Of...
# 16  [Long-term side effects of Zepbound, Comparati...
# 17  [Long-term effectiveness and cost-savings of w...
# 18  [Effectiveness and safety profile of Eli Lilly...
# 19  [Long-term safety and real-world effectiveness...
# 20  [Long-term safety data of GLP-1 products from ...
# 21  [Factors contributing to the worldwide shortag...
# 22  [Eli Lilly Ozempic risks and side effects, Cli...
# 23  [Long-term comparative studies on the cardiova...
# 24  [Long-term clinical trials of Semaglutide and ...
# 25  [Long-term impact of weight-loss medicines on ...
# 26  [Long-term benefits of Ozempic and Wegovy, Com...
# 27  [Long-term effects of GLP-1 medications on mus...
# 28  [FDA regulations on compounding pharmacies and...
# 29  [Clinical studies on Mounjaro and its potentia...
# 30  [Long-term impact of weight loss drugs on cons...
# 31  [FDA regulations on off-label usage of medicat...
# 32  [Eli Lilly Ozempic market share, Comparison of...
# 33  [Long-term clinical studies on the safety and ...
# 34  [Long-term safety and efficacy of off-label us...
# 35  [Incidence of severe stomach issues in non-med...
# 36  [Eli Lilly Ozempic safety and efficacy studies...
# 37  [Weight-loss pill market analysis, Comparison ...
# 38  [Long-term clinical outcomes of GLP-1 drugs li...
# 39  [Long-term safety studies of GLP-1 drugs from ...
# 40  [Detailed analysis of the epidemiological stud...
# 41  [FDA inspection report details for Ozempic and...
# 42  [Long-term studies on the safety and efficacy ...
# 43  [Eli Lilly Ozempic FLOW study interim analysis...
# 44  [Long-term safety data GLP-1 drugs Eli Lilly a...
# 45  [Independent testing of alleged counterfeit Mo...
# 46  [Clinical studies on the severity and duration...
# 47  [Consumer behavior fast food consumption, GLP-...
# 48  [Patient feedback on the compounded versions o...
# 49  [Long-term side effects of Ozempic and other w...
#
# [50 rows x 23 columns]
